# %% [markdown]
# # Rizli Avriananda Anshari (Pre-Test DSA)

# %% [markdown]
# ## Load Library

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("churn.csv", encoding='latin1')
df.head(10)
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
# 5      1             118        510          3355                   1
# 6     19             121        510          1516                   0
# 7     24             147        415           116                   1
# 8     18             117        408           425                   0
# 9     49             141        415           163                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# ...

# %%
df.groupby("class").count()
# Out:
#        state  account_length  area_code  phone_number  international_plan  \
# class
# 0       4293            4293       4293          4293                4293
# 1        707             707        707           707                 707
#
#        voice_mail_plan  number_vmail_messages  total_day_minutes  \
# class
# 0                 4293                   4293               4293
# 1                  707                    707                707
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# class
# 0                 4293              4293               4293             4293
# 1                  707               707                707              707
#
#        total_eve_charge  total_night_minutes  total_night_calls  \
# class
# 0                  4293                 4293               4293
# 1                   707                  707                707
#
#        total_night_charge  total_intl_minutes  total_intl_calls  \
# class
# ...

# %% [markdown]
# ## Calculate Non-Churn Customers MoU/Subs

# %%
subset_df_1 = df[df['class'] == 0]
(sum(subset_df_1['total_day_minutes'])+sum(subset_df_1['total_eve_minutes'])+sum(subset_df_1['total_intl_minutes']))/4293
# Out:
# 384.7424644770554

# %% [markdown]
# ## Calculate Churner Customers MoU/Subs

# %%
subset_df_0 = df[df['class'] == 1]
(sum(subset_df_0['total_day_minutes'])+sum(subset_df_0['total_eve_minutes'])+sum(subset_df_0['total_intl_minutes']))/707
# Out:
# 430.3207920792078

# %% [markdown]
# ## Calculate Non-Churn Customers CS Calls

# %%
sum(subset_df_1['number_customer_service_calls'])/4293
# Out:
# 1.4577218728162125

# %%
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
# 5      1             118        510          3355                   1
# 6     19             121        510          1516                   0
# 7     24             147        415           116                   1
# 8     18             117        408           425                   0
# 9     49             141        415           163                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# ...

# %% [markdown]
# ## Calculate Churn Customers CS Calls

# %%
sum(subset_df_0['number_customer_service_calls'])/707
# Out:
# 2.2545968882602545

# %% [markdown]
# ## Calculate Non-Churn Customers Number of Voice Messages

# %%
sum(subset_df_1['number_vmail_messages'])/4293
# Out:
# 8.29187048683904

# %% [markdown]
# ## Calculate Churn Customers Number of Voice Messages

# %%
sum(subset_df_0['number_vmail_messages'])/707
# Out:
# 4.496463932107496

# %% [markdown]
# ## Calculate Non-Churn Customers International Plan

# %%
sum(subset_df_1['international_plan'])/4293
# Out:
# 0.06382483112042861

# %% [markdown]
# ## Calculate Churn Customers International Plan

# %%
sum(subset_df_0['international_plan'])/707
# Out:
# 0.2814710042432815
